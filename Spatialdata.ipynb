# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhamkumar0502/Data-Handling-and-Visualization-/blob/main/Spatialdata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.2.2)

# %%
import folium
mymap = folium.Map(location = [1.366623, 103.821285],
                   width = 950,
                   height = 550,
                   zoom_start = 12,
                   titles = 'opentstreetmap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a0c91b79da7017895eb03a3596804bf {
#                     position: relative;
#                     width: 950.0px;
#                     height: 550.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a0c91b79da7017895eb03a3596804bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a0c91b79da7017895eb03a3596804bf = L.map(
#                 &quot;map_9a0c91b79da7017895eb03a3596804bf&quot;,
#                 {
#                     center: [1.366623, 103.821285],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     titles: &quot;opentstreetmap&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ebdb8271bcdbbe7c82b28b8413e6a7e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a0c91b79da7017895eb03a3596804bf);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
mymap = folium.Map(location=[13.05, 77.6], zoom_start=12)  # Adjust location and zoom level as needed

# Create a list of locations with coordinates and image URLs
locations = [
    {"name": "Electronic City", "lat": 12.9985954, "lon": 77.5920086, "img": "https://im.hunt.in/cg/City-Guide/elec.jpg", "bounds": [ [12.98, 77.58], [13.02, 77.60] ]},
    {"name": "Bannerghatta Road", "lat": 12.9596466, "lon": 77.5736842, "img": "https://static.toiimg.com/photo/40193882/.jpg", "bounds": [ [12.94, 77.56], [12.98, 77.58] ]},
    {"name": "HSR Layout", "lat": 12.9797454, "lon": 77.5906167, "img": "https://upload.wikimedia.org/wikipedia/commons/7/7b/2%2C_Park_-_HSR_Layout%2C_Bengaluru.jpg", "bounds": [ [12.97, 77.58], [12.98, 77.59] ]},
    {"name": "Koramangala", "lat": 12.974244, "lon": 77.592195, "img": "https://imgmediagumlet.lbb.in/media/2022/01/61efa39514a08c2400a7ce56_1643094933277.png?fm=webp&w=750&h=500&dpr=1", "bounds": [ [12.97, 77.59], [12.98, 77.60] ]}
]

# Add markers with custom popups
for location in locations:
    # Create a marker for the location
    marker = folium.Marker(location=[location["lat"], location["lon"]])

    # Create a custom popup with the image and location name
    popup_html = folium.Popup(folium.IFrame(html=f'<b>{location["name"]}</b><br><img src="{location["img"]}" width="200">', width=200, height=200))

    # Add the popup to the marker
    marker.add_child(popup_html)

    # Add the marker to the map
    marker.add_to(mymap)
#Display the map
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f25681a66842e208f82ab3eca1166f00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f25681a66842e208f82ab3eca1166f00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f25681a66842e208f82ab3eca1166f00 = L.map(
#                 &quot;map_f25681a66842e208f82ab3eca1166f00&quot;,
#                 {
#                     center: [13.05, 77.6],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8be45bf6fe168179bd50a8051acdbf21 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f25681a66842e208f82ab3eca1166f00);
#
#
#             var marker_6c2e9395984056de9317db54dbe94bee = L.marker(
#                 [12.9985954, 77.5920086],
#                 {}
#             ).addTo(map_f25681a66842e208f82ab3eca1166f00);
#
#
#         var popup_42cc6e98f7b8d57d83c1a77de2280802 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_6c87d5fbfb57fb4c119e69f894a0c1ce = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8Yj5FbGVjdHJvbmljIENpdHk8L2I+PGJyPjxpbWcgc3JjPSJodHRwczovL2ltLmh1bnQuaW4vY2cvQ2l0eS1HdWlkZS9lbGVjLmpwZyIgd2lkdGg9IjIwMCI+&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_42cc6e98f7b8d57d83c1a77de2280802.setContent(i_frame_6c87d5fbfb57fb4c119e69f894a0c1ce);
#
#
#
#         marker_6c2e9395984056de9317db54dbe94bee.bindPopup(popup_42cc6e98f7b8d57d83c1a77de2280802)
#         ;
#
#
#
#
#             var marker_6b18359270759887b37aae1aee18f0fa = L.marker(
#                 [12.9596466, 77.5736842],
#                 {}
#             ).addTo(map_f25681a66842e208f82ab3eca1166f00);
#
#
#         var popup_dff09c864944014d3e463b864ef73cde = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_09f0f73812acd32256171230796f187b = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8Yj5CYW5uZXJnaGF0dGEgUm9hZDwvYj48YnI+PGltZyBzcmM9Imh0dHBzOi8vc3RhdGljLnRvaWltZy5jb20vcGhvdG8vNDAxOTM4ODIvLmpwZyIgd2lkdGg9IjIwMCI+&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_dff09c864944014d3e463b864ef73cde.setContent(i_frame_09f0f73812acd32256171230796f187b);
#
#
#
#         marker_6b18359270759887b37aae1aee18f0fa.bindPopup(popup_dff09c864944014d3e463b864ef73cde)
#         ;
#
#
#
#
#             var marker_0c91294c156db3285ef7f3fa58554729 = L.marker(
#                 [12.9797454, 77.5906167],
#                 {}
#             ).addTo(map_f25681a66842e208f82ab3eca1166f00);
#
#
#         var popup_d80b48bae23877b9a399cbb89ccc0f3a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_2cc0f4f6380f05b95f0871f9f75fc1f2 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8Yj5IU1IgTGF5b3V0PC9iPjxicj48aW1nIHNyYz0iaHR0cHM6Ly91cGxvYWQud2lraW1lZGlhLm9yZy93aWtpcGVkaWEvY29tbW9ucy83LzdiLzIlMkNfUGFya18tX0hTUl9MYXlvdXQlMkNfQmVuZ2FsdXJ1LmpwZyIgd2lkdGg9IjIwMCI+&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_d80b48bae23877b9a399cbb89ccc0f3a.setContent(i_frame_2cc0f4f6380f05b95f0871f9f75fc1f2);
#
#
#
#         marker_0c91294c156db3285ef7f3fa58554729.bindPopup(popup_d80b48bae23877b9a399cbb89ccc0f3a)
#         ;
#
#
#
#
#             var marker_fcce714d75132c15fba45343ad516ce5 = L.marker(
#                 [12.974244, 77.592195],
#                 {}
#             ).addTo(map_f25681a66842e208f82ab3eca1166f00);
#
#
#         var popup_de0b21e0fb09f056c87d55f536a97c86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var i_frame_fbdbc0b68f8373b44e9a3f46d8a9dd73 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8Yj5Lb3JhbWFuZ2FsYTwvYj48YnI+PGltZyBzcmM9Imh0dHBzOi8vaW1nbWVkaWFndW1sZXQubGJiLmluL21lZGlhLzIwMjIvMDEvNjFlZmEzOTUxNGEwOGMyNDAwYTdjZTU2XzE2NDMwOTQ5MzMyNzcucG5nP2ZtPXdlYnAmdz03NTAmaD01MDAmZHByPTEiIHdpZHRoPSIyMDAiPg==&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;200&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_de0b21e0fb09f056c87d55f536a97c86.setContent(i_frame_fbdbc0b68f8373b44e9a3f46d8a9dd73);
#
#
#
#         marker_fcce714d75132c15fba45343ad516ce5.bindPopup(popup_de0b21e0fb09f056c87d55f536a97c86)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none
